# %% [markdown]
# Schreiben Sie Code, der Ihnen die Zahlen von 10 bis 5 in absteigender Reihenfolge ausgibt.

# %%
for x in range(10,4,-1):
    print(x)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %% [markdown]
# Bei Antworten die richtig sind, setzen Sie vor den Fragebuchstaben eine 1, bei Antworten die falsch sind eine 0.
#
#
#
# Welche Aussagen treffen auf while-Schleifen zu?

# %% [markdown]
# 1 a)Durchlauf ist abhängig von einem bool'schen Ausdruck
#
# 0 b)Mit break brechen Sie den aktuellen Durchlauf ab und setzen beim nächsten Durchlauf fort
#
# 1 c)Mit break brechen Sie die Schleife komplett ab
#
# 0 d)Die Zeile mit dem Schlüsselwort while ist als Steueranweisung mit Strichpunkt abzuschliessen
